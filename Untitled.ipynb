# %%
import pandas as pd

dataset = pd.read_excel("data.xlsx")


dataset.head()
# Out:
#    country country_code year_week     level region region_name  new_cases  \
# 0  Austria           AT  2020-W15  national     AT     Austria     1838.0
# 1  Austria           AT  2020-W16  national     AT     Austria      684.0
# 2  Austria           AT  2020-W17  national     AT     Austria      448.0
# 3  Austria           AT  2020-W18  national     AT     Austria      312.0
# 4  Austria           AT  2020-W19  national     AT     Austria      264.0
#
#    tests_done  population  testing_rate  positivity_rate testing_data_source
# 0       12339   8901064.0    138.623877        14.895859  Manual webscraping
# 1       58488   8901064.0    657.089984         1.169471  Manual webscraping
# 2       33443   8901064.0    375.719128         1.339593  Manual webscraping
# 3       26598   8901064.0    298.818209         1.173021     Country website
# 4       42153   8901064.0    473.572598         0.626290     Country website
